# %%
from race_model.data_sources import openf1

# %%
sessions = openf1.sessions.fetch(years=[2024, 2025, 2026], circuit_names=["Melbourne", "Monza"])

sessions

# %%
stints = openf1.stints.fetch(session_keys=sessions.session_key)

stints

# %%
laps = openf1.laps.fetch(session_keys=sessions.session_key)

laps
